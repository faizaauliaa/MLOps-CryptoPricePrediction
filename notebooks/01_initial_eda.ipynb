# %% [markdown]
# # Initial Exploratory Data Analysis
#
# This notebook contains the initial exploratory data analysis for the cryptocurrency price prediction project.
#
# ## Objectives
# - Understand the structure of cryptocurrency market data.
# - Inspect data quality and completeness.
# - Identify initial patterns in OHLCV data.
# - Prepare considerations for further feature engineering and model development.

# %%
import pandas as pd
import numpy as np

print("Initial EDA environment is ready.")
print("Project: MLOps Crypto Price Prediction")
# Out:
# Initial EDA environment is ready.
# Project: MLOps Crypto Price Prediction
